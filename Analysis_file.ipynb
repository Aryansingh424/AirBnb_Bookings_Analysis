# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset

dir_path = ('C:/Users/My PC/AirBnb_Bookings_Analysis/Airbnb_RAW_DATA.csv')

# %%
# Dataset First Look

AirBnb_df = pd.read_csv(dir_path)
AirBnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
AirBnb_df.head(20)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 11  5441                   Central Manhattan/near Broadway     7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# ...

# %%
# Dataset Rows & Columns count
AirBnb_df.shape
# Out:
# (48895, 16)

# %%
# dataset information

AirBnb_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Dataset Duplicate Value Count

def check_duplicates():

    try:
        dup_count = AirBnb_df.duplicated().sum()

        return dup_count 

    except Exception as e:

        print("please give relatable data")

# %%
how_many_duplicate_rows = check_duplicates()

print(f'The total number of duplicate rows excluding first occurence {how_many_duplicate_rows}')
# Out:
# The total number of duplicate rows excluding first occurence 0

# %%
# (The total number of duplicate rows excluding first occurence 0 ) 
# This output states that there are no duplicates rows in the given data

# %%
# counting null values for each column separately

null_values = AirBnb_df.isna().sum()
print(null_values)
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# counting total number of null values in the data frame 

null_values = null_values.sum()
print(null_values)
# Out:
# 20141

# %%
# visualizing the missing Values 


plt.figure(figsize = (10,50))
AirBnb_df.isna().sum().plot(kind='bar')
plt.title('Null Values Visualization')
plt.xlabel('Columns of DataFrame')
plt.ylabel('Numbers of Rows')
plt.xticks(rotation = 60)
plt.ylim(0, len(AirBnb_df))

# figure size column is 50 because there are very few null values in name and host name also which might not be visible at 10, 5 view
# Out:
# (0.0, 48895.0)

# %%
# total columns in Data set 

AirBnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='str')

# %%
# describing data set

AirBnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Variable description 

# finding host_id = unique host id 

AirBnb_df['host_id'].nunique()
# Out:
# 37457

# %%
print(len(AirBnb_df['host_id'].unique()))
# Out:
# 37457

# %%
AirBnb_df["host_id"].duplicated()
# this means that one host can have multiple listing that is why unique id are less than total ids
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890     True
# 48891     True
# 48892    False
# 48893     True
# 48894    False
# Name: host_id, Length: 48895, dtype: bool

# %%
# code with simplest approach

total_duplicates_in_host_id = AirBnb_df["host_id"].duplicated().sum()
total_ids_in_AirBnb_df = len(AirBnb_df)

total_unique_host_ids = total_ids_in_AirBnb_df - total_duplicates_in_host_id
print(total_unique_host_ids)
# Out:
# 37457

# %%
# so the total number of unique hosts that visited the hotel are 37457

# %%
plt.figure(figsize=(10,6))
AirBnb_df['host_id'].value_counts().head(20).plot(kind='bar')
plt.title("Host listings ")
plt.xlabel("host id's")
plt.ylabel("No. of listings each host has")
# Out:
# Text(0, 0.5, 'No. of listings each host has')

# %%
# pricing analysis

# %%
AirBnb_df["price"].isna().sum()
# Out:
# np.int64(0)

# %%
list_=list(AirBnb_df["price"])

# %%
max(list_)
# Out:
# 10000

# %%
# now we know max price of a hotel is 10000 or we can do

# %%
# most expensive listings are :

AirBnb_df[AirBnb_df["price"]==AirBnb_df["price"].max()]
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0         NaN
#
# ...

# %%
# most cheapest listings are :

AirBnb_df[AirBnb_df["price"]==AirBnb_df["price"].min()]
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %%
# Total revenue generated

# %%
def total_rev():
    
    try:

        total_sum = AirBnb_df["price"].sum()
        return total_sum
    
    except Exception as e:
       
       print("Error occured")

# %%
total_revenue = total_rev()

print(f"total revenue is {total_revenue}")
# Out:
# total revenue is 7467278

# %%
# Average of overall price that has been earned is :

# %%
total_number_of_price = len(AirBnb_df["price"])
Sum_of_price = AirBnb_df["price"].sum()

def avrg():

    try:
        Average = Sum_of_price/total_number_of_price
        return Average
    
    except Exception as e:
        print("error occured")

    finally:
        print("Average is calculated successfuly")

Average_of_price = avrg()

print(f"Average of overall price is {Average_of_price}")
# Out:
# Average is calculated successfuly
# Average of overall price is 152.7206871868289

# %%
AirBnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='str')

# %%
# visualization 

plt.scatter(AirBnb_df["price"],AirBnb_df['reviews_per_month'])
plt.title("Price Trend Chart")
plt.xlabel("price")
plt.ylabel("reviews per month")
# Out:
# Text(0, 0.5, 'reviews per month')
